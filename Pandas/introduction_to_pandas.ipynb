# %% [markdown]
# <a href="https://colab.research.google.com/github/hafilmr/LearningCodeTrainee/blob/main/Pandas/introduction_to_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Datatypes
#
# pandas has two main datatypes, Series and DataFrame.
#
# * Series - a 1-dimensional column of data.
# * DataFrame (most common) - a 2-dimesional table of data with rows and columns.

# %%
# You can create a Series using pd.Series() and passing it a Python list.

# 2 main data types
series = pd.Series(["BMW", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = 1-dimensional

# %%
colours = pd.Series (["Red", "Blue" "White"])
colours
# Out:
# 0          Red
# 1    BlueWhite
# dtype: object

# %%
# dataframe = 2-dimensional

# %%
car_data = pd.DataFrame ({"Car make": series, "Colours": colours})
car_data
# Out:
#   Car make    Colours
# 0      BMW        Red
# 1   Toyota  BlueWhite
# 2    Honda        NaN

# %%
# import data

car_sales = pd.read_csv("/content/7.1 car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv("exported_car-sales.csv", index=False)
# export data frame to csv

# %%
exported_car_sales = pd.read_csv("/content/exported_car-sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## DESCRIBE DATA

# %%
# Attribute
car_sales.dtypes

# Function
# car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()

# giving statistical information
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()

# giving information such index, null column, etc
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series ([3000, 1500, 111250])
car_prices.mean()
# Out:
# 38583.333333333336

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()

# reading 1 columns using ["NAMA COLUMNS"]
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## VIEWING and SELECTING DATA

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head()

# normally, function head take 5 first row
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()

# function tail take 5 last rows
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
#.loc & .iloc

animals = pd.Series(["cat", "dog", "bird", "panda", "snake"], 
                    index=[0, 3, 9, 8, 3])

# %% [markdown]
# ?.ILOC untuk mendapatkan value berdasarkan urutan index
#
# .LOC untuk mendapatkan value berdasarkan nomer index

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'panda'

# %%
animals.iloc[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-6a616614b504> in <module>()
# ----> 1 animals.iloc[9]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1494
#    1495             # validate the location
# -> 1496             self._validate_integer(key, axis)
#    1497
#    1498             return self.obj._ixs(key, axis=axis)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1435         len_axis = len(self.obj._get_axis(axis))
# ...

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
animals.iloc[3:]
# Out:
# 8    panda
# 3    snake
# dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# car_sales.Odometer (KM)

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# GROUPBY
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()

# %%
car_sales["Odometer (KM)"].hist()

# %%
car_sales['Price'].dtype
# Out:
# dtype('O')

# %%
car_sales['Price'].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-acc32476974d> in <module>()
# ----> 1 car_sales['Price'].plot()
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     267     def generate(self):
# ...

# %% [markdown]
# cause column price have dtype object, it cant to plot. so we must convert this to numerical

# %%
car_sales["Price"]=car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales['Price'].plot()

# %% [markdown]
# ## MANIPULATE DATA

# %%
car_sales["Make"].str.lower()

# lowering case
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# make a change for lowering case in columns make

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales_missing = pd.read_csv("/content/9.2 car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing['Odometer'].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing['Odometer'] = car_sales_missing['Odometer'].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()

# %%
car_sales_missing_dropped
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing_dropped.to_csv("car_sales_missing_dropped.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
# Column from Series

seats_column = pd.Series([5, 5, 5, 5, 5])

#New Column called seats
car_sales["Seats"]= seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    NaN
# 6   honda   Blue          45698      4   750000    NaN
# 7   honda   Blue          54738      4   700000    NaN
# 8  toyota  White          60000      4   625000    NaN
# 9  nissan  White          31600      4   970000    NaN

# %%
car_sales['Seats'].fillna(5, inplace=True)

# fungsi inplace= TRUE tuh sebenernya biar ada perubahan langsung bisa disave

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    5.0
# 6   honda   Blue          45698      4   750000    5.0
# 7   honda   Blue          54738      4   700000    5.0
# 8  toyota  White          60000      4   625000    5.0
# 9  nissan  White          31600      4   970000    5.0

# %%
# Column from Python List

fuel_economy = [7.5 , 6, 9, 8.9, 10.5, 4.8, 5.6, 8, 9, 6.8]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             6.0
# 2  toyota   Blue          32549      3   700000    5.0             9.0
# 3     bmw  Black          11179      5  2200000    5.0             8.9
# 4  nissan  White         213095      4   350000    5.0            10.5
# 5  toyota  Green          99213      4   450000    5.0             4.8
# 6   honda   Blue          45698      4   750000    5.0             5.6
# 7   honda   Blue          54738      4   700000    5.0             8.0
# 8  toyota  White          60000      4   625000    5.0             9.0
# 9  nissan  White          31600      4   970000    5.0             6.8

# %%
car_sales['Total Fuel Used (Liter)'] = car_sales["Odometer (KM)"]/100 * car_sales['Fuel per 100KM']
car_sales
# Out:
#      Make Colour  Odometer (KM)  ...  Seats  Fuel per 100KM  Total Fuel Used (Liter)
# 0  toyota  White         150043  ...    5.0             7.5                11253.225
# 1   honda    Red          87899  ...    5.0             6.0                 5273.940
# 2  toyota   Blue          32549  ...    5.0             9.0                 2929.410
# 3     bmw  Black          11179  ...    5.0             8.9                  994.931
# 4  nissan  White         213095  ...    5.0            10.5                22374.975
# 5  toyota  Green          99213  ...    5.0             4.8                 4762.224
# 6   honda   Blue          45698  ...    5.0             5.6                 2559.088
# 7   honda   Blue          54738  ...    5.0             8.0                 4379.040
# 8  toyota  White          60000  ...    5.0             9.0                 5400.000
# 9  nissan  White          31600  ...    5.0             6.8                 2148.800
#
# [10 rows x 8 columns]

# %%
# Create a column from a single value

car_sales["Number of Wheels"] = 4
car_sales
# Out:
#      Make Colour  ...  Total Fuel Used (Liter)  Number of Wheels
# 0  toyota  White  ...                11253.225                 4
# 1   honda    Red  ...                 5273.940                 4
# 2  toyota   Blue  ...                 2929.410                 4
# 3     bmw  Black  ...                  994.931                 4
# 4  nissan  White  ...                22374.975                 4
# 5  toyota  Green  ...                 4762.224                 4
# 6   honda   Blue  ...                 2559.088                 4
# 7   honda   Blue  ...                 4379.040                 4
# 8  toyota  White  ...                 5400.000                 4
# 9  nissan  White  ...                 2148.800                 4
#
# [10 rows x 9 columns]

# %%
car_sales['Passed Road Safety'] = True
car_sales.dtypes
# Out:
# Make                        object
# Colour                      object
# Odometer (KM)                int64
# Doors                        int64
# Price                        int64
# Seats                      float64
# Fuel per 100KM             float64
# Total Fuel Used (Liter)    float64
# Number of Wheels             int64
# Passed Road Safety            bool
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  ...  Number of Wheels  Passed Road Safety
# 0  toyota  White  ...                 4                True
# 1   honda    Red  ...                 4                True
# 2  toyota   Blue  ...                 4                True
# 3     bmw  Black  ...                 4                True
# 4  nissan  White  ...                 4                True
# 5  toyota  Green  ...                 4                True
# 6   honda   Blue  ...                 4                True
# 7   honda   Blue  ...                 4                True
# 8  toyota  White  ...                 4                True
# 9  nissan  White  ...                 4                True
#
# [10 rows x 10 columns]

# %%
# car_sales.drop('Total Fuel Used', axis=1, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  ...  Number of Wheels  Passed Road Safety
# 0  toyota  White  ...                 4                True
# 1   honda    Red  ...                 4                True
# 2  toyota   Blue  ...                 4                True
# 3     bmw  Black  ...                 4                True
# 4  nissan  White  ...                 4                True
# 5  toyota  Green  ...                 4                True
# 6   honda   Blue  ...                 4                True
# 7   honda   Blue  ...                 4                True
# 8  toyota  White  ...                 4                True
# 9  nissan  White  ...                 4                True
#
# [10 rows x 10 columns]

# %%
car_sales.sample(frac=0.5)

# randomizing data
# Out:
#      Make Colour  ...  Number of Wheels  Passed Road Safety
# 1   honda    Red  ...                 4                True
# 5  toyota  Green  ...                 4                True
# 3     bmw  Black  ...                 4                True
# 0  toyota  White  ...                 4                True
# 4  nissan  White  ...                 4                True
#
# [5 rows x 10 columns]

# %%
car_sales
# Out:
#      Make Colour  ...  Number of Wheels  Passed Road Safety
# 0  toyota  White  ...                 4                True
# 1   honda    Red  ...                 4                True
# 2  toyota   Blue  ...                 4                True
# 3     bmw  Black  ...                 4                True
# 4  nissan  White  ...                 4                True
# 5  toyota  Green  ...                 4                True
# 6   honda   Blue  ...                 4                True
# 7   honda   Blue  ...                 4                True
# 8  toyota  White  ...                 4                True
# 9  nissan  White  ...                 4                True
#
# [10 rows x 10 columns]

# %%
car_sales_shuffled = car_sales.sample(frac=0.5)
car_sales_shuffled
# Out:
#      Make Colour  ...  Number of Wheels  Passed Road Safety
# 9  nissan  White  ...                 4                True
# 4  nissan  White  ...                 4                True
# 8  toyota  White  ...                 4                True
# 5  toyota  Green  ...                 4                True
# 0  toyota  White  ...                 4                True
#
# [5 rows x 10 columns]

# %%
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  ...  Number of Wheels  Passed Road Safety
# 5  toyota  Green  ...                 4                True
#
# [1 rows x 10 columns]

# %%
car_sales_shuffled
# Out:
#      Make Colour  ...  Number of Wheels  Passed Road Safety
# 9  nissan  White  ...                 4                True
# 4  nissan  White  ...                 4                True
# 8  toyota  White  ...                 4                True
# 5  toyota  Green  ...                 4                True
# 0  toyota  White  ...                 4                True
#
# [5 rows x 10 columns]

# %%
car_sales_shuffled.reset_index(drop=True)

# drop true untuk menghilangkan index
# Out:
#      Make Colour  ...  Number of Wheels  Passed Road Safety
# 0  nissan  White  ...                 4                True
# 1  nissan  White  ...                 4                True
# 2  toyota  White  ...                 4                True
# 3  toyota  Green  ...                 4                True
# 4  toyota  White  ...                 4                True
#
# [5 rows x 10 columns]

# %%
car_sales_shuffled
# Out:
#      Make Colour  ...  Number of Wheels  Passed Road Safety
# 9  nissan  White  ...                 4                True
# 4  nissan  White  ...                 4                True
# 8  toyota  White  ...                 4                True
# 5  toyota  Green  ...                 4                True
# 0  toyota  White  ...                 4                True
#
# [5 rows x 10 columns]

# %%
car_sales['Odometer (KM)'] = car_sales['Odometer (KM)'].apply(lambda x: x / 1.6)
car_sales
# Out:
#      Make Colour  ...  Number of Wheels  Passed Road Safety
# 0  toyota  White  ...                 4                True
# 1   honda    Red  ...                 4                True
# 2  toyota   Blue  ...                 4                True
# 3     bmw  Black  ...                 4                True
# 4  nissan  White  ...                 4                True
# 5  toyota  Green  ...                 4                True
# 6   honda   Blue  ...                 4                True
# 7   honda   Blue  ...                 4                True
# 8  toyota  White  ...                 4                True
# 9  nissan  White  ...                 4                True
#
# [10 rows x 10 columns]
